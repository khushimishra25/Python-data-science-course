# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter, ImageEnhance, ImageCms

# %%
im1 = Image.open('image.jpg')
print(im1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=259x194 at 0x2032EE1B5B0>

# %%
im1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=259x194>

# %%
im2 = Image.open('image2.jpg')

# %%
im2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=221x228>

# %%
print(im1.info)
print(im1.format)
print(im1.mode)
# Out:
# {}
# PNG
# P

# %%
im2.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGB size=221x228>

# %%
#resizing
#im11 = im1.resize((200,200))
#im11.rotate(45).save('oimage_rot_45.jpg)
#to save rotated image

# %%
im2.size
# Out:
# (221, 228)

# %%
# cropping
im2.crop((60,5,170,100)).show()

# %%
im2.crop((60,5,170,100))
# Out:
# <PIL.Image.Image image mode=RGB size=110x95>

# %%
im2 = im2.resize(im1.size)

# %%
im2.convert(im1.mode)
print(im2.mode,im1.mode)
print(im2.size,im1.size)
# Out:
# RGB P
# (259, 194) (259, 194)

# %%
#merging two images
Image.blend(im2, im1,.5).show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\digi\image_processing\pillow_basics.ipynb Cell 14 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/digi/image_processing/pillow_basics.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> #merging two images
# ----> <a href='vscode-notebook-cell:/c%3A/digi/image_processing/pillow_basics.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> Image.blend(im2, im1,.5).show()
#
# File c:\Users\Dell\miniconda3\lib\site-packages\PIL\Image.py:3230, in blend(im1, im2, alpha)
#    3228 im1.load()
#    3229 im2.load()
# -> 3230 return im1._new(core.blend(im1.im, im2.im, alpha))
#
# ValueError: image has wrong mode

# %%
logo = Image.open('image3.png')

# %%
im2c = im2.copy()
im2c.paste(logo,(2,2))
im2c.show()
