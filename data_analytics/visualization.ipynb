# %% [markdown]
# VISUALISATION
# - figure
# - axes
# - plot
# - pie
# - bar
# - scatter
# - hist
# - box
# - step
# - subplots

# %%
import matplotlib.pyplot as plt
import numpy as np']

# %%
y = [21,345,56,12,5,47,1]
plt.plot(y)

# %%
plt.figure(figsize=(5,5))
plt.pie(y)
plt.show()  # for removing unecessary data from display

# %%
fig,ax=plt.subplots(nrows=2,ncols=1)
plt.show()

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(15,2))
plt.show()

# %%
t=np.arange(-3*np.pi,3*np.pi,0.2)
x=np.sin(t)
y=np.cos(t)
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(15,2))
ax[0].plot(t,x,'r')
ax[1].bar(t,y)
plt.show()

# %%
t=np.arange(-3*np.pi,3*np.pi,0.2)
x=np.sin(t)
y=np.cos(t)
fig,ax=plt.subplots(nrows=2,ncols=1,figsize=(10,6))
ax[0].plot(t,x,'r')
ax[1].bar(t,y)
plt.show()

# %%
x=[100,200,300,400,500,600,700,800,900,1000]
y=[23,45,1,34,65,2,2,46,34,56,]
plt.plot(x,y,linewidth=2,color="purple",marker='p',markersize=8, markerfacecolor="pink",markeredgecolor="blue"
,linestyle=':')    #marker="s or * or x" linestyle='--'

# %%
plt.plot?
# Out:
# Signature: plt.plot(*args, scalex=True, scaley=True, data=None, **kwargs)
# Docstring:
# Plot y versus x as lines and/or markers.
#
# Call signatures::
#
#     plot([x], y, [fmt], *, data=None, **kwargs)
#     plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# The coordinates of the points or line nodes are given by *x*, *y*.
#
# The optional parameter *fmt* is a convenient way for defining basic
# formatting like color, marker and linestyle. It's a shortcut string
# notation described in the *Notes* section below.
#
# >>> plot(x, y)        # plot x and y using default line style and color
# >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
# >>> plot(y)           # plot y using x as index array 0..N-1
# >>> plot(y, 'r+')     # ditto, but with red plusses
#
# You can use `.Line2D` properties as keyword arguments for more
# control on the appearance. Line properties and *fmt* can be mixed.
# The following two calls yield identical results:
#
# ...

# %%
plt.plot(x,y,linewidth=2,color="purple",marker='p',markersize=8, markerfacecolor="pink",markeredgecolor="blue"
,linestyle=':')
plt.title("Some graph is showing",fontdict={'fontsize':15,'fontweight':'light','color':'blue'})
plt.xlabel("X axis ki values",fontdict={'color':'blue'})
plt.ylabel("Y axis ki values",fontdict={'color':'blue'})
plt.text(600,60,"This is serious \npoint here")
plt.annotate("Peak value",xy=(500,65),xytext=(600,50), arrowprops=dict(facecolor="black",width=1))
plt.show()
